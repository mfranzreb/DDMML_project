# %% [markdown]
# # Remaining Life Prediction for Turbofan Engine - Regression

# %% [markdown]
# ## Data Exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from turbofan_importFDdata import turbofan_importFDdata

# %% [markdown]
# **Loading the dataset FD002**

# %%
data = turbofan_importFDdata('train_FD002.txt')
data_test = turbofan_importFDdata('test_FD002.txt')

# data

# %% [markdown]
# **Operational Settings**

# %%
data.loc[:,'Unit':'Setting3']
# Out:
#        Unit  Time  Setting1  Setting2  Setting3
# 0         1     1   34.9983    0.8400     100.0
# 1         1     2   41.9982    0.8408     100.0
# 2         1     3   24.9988    0.6218      60.0
# 3         1     4   42.0077    0.8416     100.0
# 4         1     5   25.0005    0.6203      60.0
# ...     ...   ...       ...       ...       ...
# 53754   260   312   20.0037    0.7000     100.0
# 53755   260   313   10.0022    0.2510     100.0
# 53756   260   314   25.0041    0.6200      60.0
# 53757   260   315   25.0033    0.6220      60.0
# 53758   260   316   35.0036    0.8400     100.0
#
# [53759 rows x 5 columns]

# %% [markdown]
# **Sensor Measurments**

# %%
data.iloc[:,5:26]
# Out:
#        FanInletTemp  LPCOutletTemp  HPCOutletTemp  LPTOutletTemp  \
# 0            449.44         555.32        1358.61        1137.23
# 1            445.00         549.90        1353.22        1125.78
# 2            462.54         537.31        1256.76        1047.45
# 3            445.00         549.51        1354.03        1126.38
# 4            462.54         537.07        1257.71        1047.93
# ...             ...            ...            ...            ...
# 53754        491.19         608.79        1495.60        1269.51
# 53755        489.05         605.81        1514.32        1324.12
# 53756        462.54         537.48        1276.24        1057.92
# 53757        462.54         537.84        1272.95        1066.30
# 53758        449.44         556.64        1374.61        1145.52
#
#        FanInletPres  BypassDuctPres  TotalHPCOutletPres  PhysFanSpeed  \
# 0              5.48            8.00              194.64       2222.65
# ...

# %% [markdown]
# #### Examplary Engine Unit: Unit 1

# %%
data.iloc[:149,5:26].describe()
# Out:
#        FanInletTemp  LPCOutletTemp  HPCOutletTemp  LPTOutletTemp  \
# count    149.000000     149.000000     149.000000     149.000000
# mean     471.633154     578.220403    1417.841141    1204.313221
# std       27.183640      38.080742     107.830438     121.094160
# min      445.000000     536.250000    1256.760000    1040.990000
# 25%      445.000000     549.510000    1352.820000    1126.680000
# 50%      462.540000     555.640000    1368.090000    1137.890000
# 75%      491.190000     607.510000    1501.820000    1309.650000
# max      518.670000     643.730000    1607.030000    1429.430000
#
#        FanInletPres  BypassDuctPres  TotalHPCOutletPres  PhysFanSpeed  \
# count    149.000000      149.000000          149.000000    149.000000
# mean       7.859262       11.348389          276.063624   2225.951141
# std        3.747489        5.619953          150.310502    145.058326
# min        3.910000        5.710000          137.570000   1915.020000
# ...
